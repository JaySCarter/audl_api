# %%
import os

import numpy as np
import pandas as pd

# %%
turnovers = ['THROWAWAY', 'DROP', 'STALL', 'CALLAHAN_THROWN']
takeaways = ['BLOCK', 'CALLAHAN', 'STALL_CAUSED', 'THROWAWAY_CAUSED']

pulls = ['PULL_OUT_OF_BOUNDS', 'PULL_INBOUNDS']

pens = ['D_PENALTY_ON_THEM', 'D_PENALTY_ON_US', 'O_PENALTY_ON_THEM', 'O_PENALTY_ON_US']

quarter_ends = ['START_OF_GAME', 'END_OF_Q1', 'HALFTIME', 'END_OF_Q3', 'GAME_OVER']
line_sets = ['SET_D_LINE', 'SET_O_LINE', 'SET_D_LINE_NO_PULL', 'SET_O_LINE_NO_PULL']
timeouts = ['THEIR_MIDPOINT_TIMEOUT', 'OUR_MIDPOINT_TIMEOUT']

other = ['REF_TIMEOUT_DISCUSSION???', 'INJURY_ON_O', 'INJURY_ON_D']

# %%
df = pd.read_csv("Flyers_Games.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)
df_home = pd.read_csv("Flyers_Games_home.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)
df_away = pd.read_csv("Flyers_Games_away.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)

# %%
df.dtypes
# Out:
# event_index          int64
# game_id              int64
# date                object
# home_team            int64
# away_team            int64
# event_counter        int64
# team_id              int64
# current_quarter    float64
# time                object
# event_type          object
# player              object
# x                  float64
# y                  float64
# o_point               bool
# d_point               bool
# point_id             int64
# our_score            int64
# their_score          int64
# line                object
# new_line            object
# dtype: object

# %%
df.loc[df['event_type'] == "GOAL"].groupby(['game_id', 'team_id'])['event_type'].count()
# Out:
# game_id  team_id
# 2884     241        18
#          242        22
# 2888     235        21
#          242        20
# 2893     241        14
#          242        15
# 2894     242        24
#          245        18
# 2895     235        24
#          242        26
# 2896     234        15
#          242        23
# 2901     234        18
#          242        26
# 2905     242        19
#          245        13
# 2908     242        12
#          245        15
# Name: event_type, dtype: int64

# %%
df_home['line'] = df_home['line'].ffill()
df_home.head(20)
# Out:
#     event_index  game_id        date  home_team  away_team  event_counter  \
# 0             0     2908  2022-06-25        245        242              0
# 1             1     2908  2022-06-25        245        242              1
# 2             2     2908  2022-06-25        245        242              2
# 3             3     2908  2022-06-25        245        242              3
# 4             4     2908  2022-06-25        245        242              4
# 5             5     2908  2022-06-25        245        242              5
# 6             6     2908  2022-06-25        245        242              6
# 7             7     2908  2022-06-25        245        242              7
# 8             8     2908  2022-06-25        245        242              8
# 9             9     2908  2022-06-25        245        242              9
# 10           10     2908  2022-06-25        245        242             10
# 11           11     2908  2022-06-25        245        242             11
# 12           12     2908  2022-06-25        245        242             12
# 13           13     2908  2022-06-25        245        242             13
# 14           14     2908  2022-06-25        245        242             14
# 15           15     2908  2022-06-25        245        242             15
# 16           16     2908  2022-06-25        245        242             16
# 17           17     2908  2022-06-25        245        242             17
# 18           18     2908  2022-06-25        245        242             18
# 19           19     2908  2022-06-25        245        242             19
#
#     team_id  current_quarter       time     event_type  \
# 0       245              1.0        NaN  START_OF_GAME
# 1       245              1.0        NaN     SET_D_LINE
# 2       245              1.0        NaN  PULL_INBOUNDS
# 3       245              1.0        NaN          BLOCK
# 4       245              1.0        NaN     POSSESSION
# 5       245              1.0        NaN     POSSESSION
# 6       245              1.0        NaN           DROP
# 7       245              1.0  Q1 11:10       SCORED_ON
# 8       245              1.0        NaN     SET_O_LINE
# 9       245              1.0        NaN     POSSESSION
# 10      245              1.0        NaN     POSSESSION
# 11      245              1.0        NaN     POSSESSION
# 12      245              1.0        NaN     POSSESSION
# 13      245              1.0        NaN     POSSESSION
# 14      245              1.0        NaN     POSSESSION
# 15      245              1.0        NaN     POSSESSION
# 16      245              1.0        NaN     POSSESSION
# 17      245              1.0        NaN     POSSESSION
# 18      245              1.0        NaN     POSSESSION
# 19      245              1.0        NaN     POSSESSION
#
#                                                player      x      y  o_point  \
# 0                                                 NaN    NaN    NaN    False
# 1   Michael Arbutine, Cody Coates, Garrett Knobel,...    NaN    NaN    False
# 2                                    Michael Arbutine   7.57  80.31    False
# 3                                    Michael Arbutine    NaN    NaN    False
# 4                                    Michael Arbutine  -0.48  39.95    False
# 5                                       Sean Plunkett   7.36  44.31    False
# 6                                     Clayton Partlow  22.91  60.61    False
# 7                                                 NaN    NaN    NaN    False
# 8   Tannon Hedges, Carl Johnson, Billy O'Bryan, Un...    NaN    NaN     True
# 9                                       Tannon Hedges   0.00  40.00     True
# 10                                        Jaime Perez  -4.78  32.72     True
# 11                                      Tannon Hedges   2.52  31.84     True
# 12                                        Adam Vinson  16.09  29.93     True
# 13                                       Carl Johnson  21.41  45.47     True
# 14                                        Unmil Patel  21.34  56.31     True
# 15                                      Billy O'Bryan   8.66  54.06     True
# 16                                      Jorge Delgado -13.17  56.11     True
# 17                                      Tannon Hedges  -1.78  63.40     True
# 18                                        Adam Vinson  19.16  66.75     True
# 19                                        Unmil Patel  14.93  80.93     True
#
#     d_point  point_id  our_score  their_score  \
# 0     False         0          0            0
# 1      True         1          0            0
# 2      True         1          0            0
# 3      True         1          0            0
# 4      True         1          0            0
# 5      True         1          0            0
# 6      True         1          0            0
# 7      True         1          0            1
# 8     False         2          0            1
# 9     False         2          0            1
# 10    False         2          0            1
# 11    False         2          0            1
# 12    False         2          0            1
# 13    False         2          0            1
# 14    False         2          0            1
# 15    False         2          0            1
# 16    False         2          0            1
# 17    False         2          0            1
# 18    False         2          0            1
# 19    False         2          0            1
#
#                                                  line
# 0                                                 NaN
# 1   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 2   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 3   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 4   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 5   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 6   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 7   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 8   ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 9   ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 10  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 11  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 12  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 13  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 14  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 15  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 16  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 17  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 18  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 19  ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...

# %%
df.sort_values(['game_id', 'point_id', 'event_counter', 'team_id']).head(25)
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 423             0     2884  2022-06-17        241        242              0
# 4125            0     2884  2022-06-17        241        242              0
# 4126            1     2884  2022-06-17        241        242              1
# 4127            2     2884  2022-06-17        241        242              2
# 424             1     2884  2022-06-17        241        242              1
# 425             2     2884  2022-06-17        241        242              2
# 426             3     2884  2022-06-17        241        242              3
# 4128            3     2884  2022-06-17        241        242              3
# 427             4     2884  2022-06-17        241        242              4
# 4129            4     2884  2022-06-17        241        242              4
# 428             5     2884  2022-06-17        241        242              5
# 4130            5     2884  2022-06-17        241        242              5
# 429             6     2884  2022-06-17        241        242              6
# 430             7     2884  2022-06-17        241        242              7
# 431             8     2884  2022-06-17        241        242              8
# 432             9     2884  2022-06-17        241        242              9
# 433            10     2884  2022-06-17        241        242             10
# 434            11     2884  2022-06-17        241        242             11
# 435            12     2884  2022-06-17        241        242             12
# 436            13     2884  2022-06-17        241        242             13
# 437            14     2884  2022-06-17        241        242             14
# 438            15     2884  2022-06-17        241        242             15
# 4131            6     2884  2022-06-17        241        242              6
# 4132            7     2884  2022-06-17        241        242              7
# 4133            8     2884  2022-06-17        241        242              8
#
#       team_id  current_quarter       time     event_type  \
# 423       241              1.0        NaN  START_OF_GAME
# 4125      242              1.0        NaN  START_OF_GAME
# 4126      242              1.0        NaN            NaN
# 4127      242              1.0        NaN            NaN
# 424       241              1.0        NaN     SET_O_LINE
# 425       241              1.0        NaN     POSSESSION
# 426       241              1.0        NaN     POSSESSION
# 4128      242              1.0        NaN     SET_D_LINE
# 427       241              1.0        NaN     POSSESSION
# 4129      242              1.0        NaN  PULL_INBOUNDS
# 428       241              1.0        NaN     POSSESSION
# 4130      242              1.0  Q1 10:55       SCORED_ON
# 429       241              1.0        NaN     POSSESSION
# 430       241              1.0        NaN     POSSESSION
# 431       241              1.0        NaN     POSSESSION
# 432       241              1.0        NaN     POSSESSION
# 433       241              1.0        NaN     POSSESSION
# 434       241              1.0        NaN     POSSESSION
# 435       241              1.0        NaN     POSSESSION
# 436       241              1.0        NaN     POSSESSION
# 437       241              1.0        NaN     POSSESSION
# 438       241              1.0  Q1 10:55            GOAL
# 4131      242              1.0        NaN     SET_O_LINE
# 4132      242              1.0        NaN     POSSESSION
# 4133      242              1.0        NaN     POSSESSION
#
#                                                  player      x       y  \
# 423                                                 NaN    NaN     NaN
# 4125                                                NaN    NaN     NaN
# 4126                                                NaN    NaN     NaN
# 4127                                                NaN    NaN     NaN
# 424   Austin Taylor, Christian Olsen, Max Thorne, Br...    NaN     NaN
# 425                                     Christian Olsen  15.44    9.10
# 426                                           Bobby Ley  -1.68   19.22
# 4128  Suraj Madiraju, Dylan Hawkins, Elijah Long, Wi...    NaN     NaN
# 427                                     Christian Olsen   9.98   16.60
# 4129                                     William Coffin -16.71  112.97
# 428                                       Austin Taylor -13.34   26.14
# 4130                                                NaN    NaN     NaN
# 429                                     Christian Olsen  11.29   24.39
# 430                                          Matt Smith   4.95   29.56
# 431                                           Bobby Ley  -1.24   26.06
# 432                                     Christian Olsen  11.94   36.40
# 433                                           Bobby Ley  12.96   27.16
# 434                                          Matt Smith   4.88   34.95
# 435                                           Bobby Ley  15.51   40.19
# 436                                          Matt Smith   1.89   34.66
# 437                                       Austin Taylor   2.04   44.70
# 438                                     Christian Olsen -10.35  104.49
# 4131  Alex Davis, Jacob Fairfax, Henry Fisher, Matt ...    NaN     NaN
# 4132                                 Matt Gouchoe-Hanas  10.63   19.99
# 4133                                         Sol Yanuck  11.32   31.43
#
#       o_point  d_point  point_id  our_score  their_score  \
# 423     False    False         0          0            0
# 4125    False    False         0          0            0
# 4126    False    False         0          0            0
# 4127    False    False         0          0            0
# 424      True    False         1          0            0
# 425      True    False         1          0            0
# 426      True    False         1          0            0
# 4128    False     True         1          0            0
# 427      True    False         1          0            0
# 4129    False     True         1          0            0
# 428      True    False         1          0            0
# 4130    False     True         1          0            1
# 429      True    False         1          0            0
# 430      True    False         1          0            0
# 431      True    False         1          0            0
# 432      True    False         1          0            0
# 433      True    False         1          0            0
# 434      True    False         1          0            0
# 435      True    False         1          0            0
# 436      True    False         1          0            0
# 437      True    False         1          0            0
# 438      True    False         1          1            0
# 4131     True    False         2          0            1
# 4132     True    False         2          0            1
# 4133     True    False         2          0            1
#
#                                                    line  \
# 423                                                 NaN
# 4125                                                NaN
# 4126                                                NaN
# 4127                                                NaN
# 424   ['Austin Taylor', 'Christian Olsen', 'Max Thor...
# 425                                                 NaN
# 426                                                 NaN
# 4128  ['Suraj Madiraju', 'Dylan Hawkins', 'Elijah Lo...
# 427                                                 NaN
# 4129                                                NaN
# 428                                                 NaN
# 4130                                                NaN
# 429                                                 NaN
# 430                                                 NaN
# 431                                                 NaN
# 432                                                 NaN
# 433                                                 NaN
# 434                                                 NaN
# 435                                                 NaN
# 436                                                 NaN
# 437                                                 NaN
# 438                                                 NaN
# 4131  ['Alex Davis', 'Jacob Fairfax', 'Henry Fisher'...
# 4132                                                NaN
# 4133                                                NaN
#
#                                                new_line
# 423                                                 NaN
# 4125                                                NaN
# 4126                                                NaN
# 4127                                                NaN
# 424   ['Austin Taylor', 'Christian Olsen', 'Max Thor...
# 425                                                 NaN
# 426                                                 NaN
# 4128  ['Suraj Madiraju', 'Dylan Hawkins', 'Elijah Lo...
# 427                                                 NaN
# 4129                                                NaN
# 428                                                 NaN
# 4130                                                NaN
# 429                                                 NaN
# 430                                                 NaN
# 431                                                 NaN
# 432                                                 NaN
# 433                                                 NaN
# 434                                                 NaN
# 435                                                 NaN
# 436                                                 NaN
# 437                                                 NaN
# 438                                                 NaN
# 4131  ['Alex Davis', 'Jacob Fairfax', 'Henry Fisher'...
# 4132                                                NaN
# 4133                                                NaN

# %% [raw]
# df_home['point_id'] = df['event_type'].isin(['SET_D_LINE', 'SET_O_LINE']).cumsum()

# %%
df_home
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 0               0     2908  2022-06-25        245        242              0
# 1               1     2908  2022-06-25        245        242              1
# 2               2     2908  2022-06-25        245        242              2
# 3               3     2908  2022-06-25        245        242              3
# 4               4     2908  2022-06-25        245        242              4
# ...           ...      ...         ...        ...        ...            ...
# 3885          410     2893  2022-04-29        242        241            410
# 3886          411     2893  2022-04-29        242        241            411
# 3887          412     2893  2022-04-29        242        241            412
# 3888          413     2893  2022-04-29        242        241            413
# 3889          414     2893  2022-04-29        242        241            414
#
#       team_id  current_quarter time         event_type  \
# 0         245              1.0  NaN      START_OF_GAME
# 1         245              1.0  NaN         SET_D_LINE
# 2         245              1.0  NaN      PULL_INBOUNDS
# 3         245              1.0  NaN              BLOCK
# 4         245              1.0  NaN         POSSESSION
# ...       ...              ...  ...                ...
# 3885      242              4.0  NaN              BLOCK
# 3886      242              4.0  NaN         POSSESSION
# 3887      242              4.0  NaN  D_PENALTY_ON_THEM
# 3888      242              4.0  NaN         POSSESSION
# 3889      242              4.0  NaN          GAME_OVER
#
#                                                  player      x      y  \
# 0                                                   NaN    NaN    NaN
# 1     Michael Arbutine, Cody Coates, Garrett Knobel,...    NaN    NaN
# 2                                      Michael Arbutine   7.57  80.31
# 3                                      Michael Arbutine    NaN    NaN
# 4                                      Michael Arbutine  -0.48  39.95
# ...                                                 ...    ...    ...
# 3885                                     Connor Russell    NaN    NaN
# 3886                                     Connor Russell   1.77  28.43
# 3887                                                NaN    NaN    NaN
# 3888                                     Suraj Madiraju  14.52  45.47
# 3889                                                NaN    NaN    NaN
#
#       o_point  d_point  point_id
# 0       False    False         0
# 1       False     True         1
# 2       False     True         1
# 3       False     True         1
# 4       False     True         1
# ...       ...      ...       ...
# 3885    False     True        34
# 3886    False     True        34
# 3887    False     True        34
# 3888    False     True        34
# 3889    False     True        34
#
# [3890 rows x 16 columns]

# %%
list(df.player[1].split(", "))

df['line'] = np.where(df['event_type'].isin(line_sets), list(df['player'].str.split(", ")), "")
df['line']
# Out:
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 0
# 1       [Michael Arbutine, Cody Coates, Garrett Knobel...
# 2
# 3
# 4
#                               ...
# 7741
# 7742
# 7743
# 7744
# 7745
# Name: line, Length: 7746, dtype: object

# %%
df['event_type'].value_counts()
df['event_type'].unique()
df['event_type'].unique()
# Out:
# array(['START_OF_GAME', 'SET_D_LINE', 'PULL_INBOUNDS', 'SCORED_ON',
#        'SET_O_LINE', 'POSSESSION', 'D_PENALTY_ON_THEM', 'GOAL',
#        'D_PENALTY_ON_US', 'THROWAWAY_CAUSED', 'THROWAWAY',
#        'THEIR_MIDPOINT_TIMEOUT', 'SET_D_LINE_NO_PULL', nan,
#        'O_PENALTY_ON_THEM', 'BLOCK', 'END_OF_Q1',
#        'REF_TIMEOUT_DISCUSSION???', 'O_PENALTY_ON_US',
#        'OUR_MIDPOINT_TIMEOUT', 'SET_O_LINE_NO_PULL', 'HALFTIME',
#        'END_OF_Q3', 'DROP', 'GAME_OVER', 'PULL_OUT_OF_BOUNDS', 'STALL',
#        'INJURY_ON_O', 'INJURY_ON_D', 'STALL_CAUSED', 'CALLAHAN',
#        'CALLAHAN_THROWN'], dtype=object)

# %%
df.loc[df['event_type'] == "CALLAHAN"]
df.loc[df['event_type'] == "CALLAHAN_THROWN"]
#df.iloc[110:120]
# df.iloc[2360:2372]
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 2366          250     2893  2022-04-29        242        241            250
#
#       team_id  current_quarter       time       event_type player     x  \
# 2366      241                3  Q3 06:46   CALLAHAN_THROWN    NaN -1.97
#
#           y  o_point  d_point line
# 2366  16.89    False     True

# %%
df['reciever'] = df['player'].shift(-1)
df['turn'] = np.where(df['event_type'].isin(turnovers), 1, 0)

# %%
df['turn'] = np.where(df['event_type'].isin(turnovers), 1, 0)
df['turn'] = np.where(df['event_type'] == "DROP", 0.5, df['turn'])
df['who_turned'] = df['turn'].shift(-1) # This isn't quite right
df['turn'] = np.where(df['event_type'].isin(turnovers), 1, df['turn'])
df
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 0               0     2894  2022-05-14        242        245              0
# 1               1     2894  2022-05-14        242        245              1
# 2               2     2894  2022-05-14        242        245              2
# 3               3     2894  2022-05-14        242        245              3
# 4               4     2894  2022-05-14        242        245              4
# ...           ...      ...         ...        ...        ...            ...
# 2559          443     2893  2022-04-29        242        241            443
# 2560          444     2893  2022-04-29        242        241            444
# 2561          445     2893  2022-04-29        242        241            445
# 2562          446     2893  2022-04-29        242        241            446
# 2563          447     2893  2022-04-29        242        241            447
#
#       team_id  current_quarter       time                 event_type  \
# 0         242                1        NaN              START_OF_GAME
# 1         242                1        NaN                 SET_D_LINE
# 2         242                1        NaN              PULL_INBOUNDS
# 3         242                1  Q1 11:13                   SCORED_ON
# 4         242                1        NaN                 SET_O_LINE
# ...       ...              ...        ...                        ...
# 2559      241                4        NaN                 POSSESSION
# 2560      241                4        NaN                  THROWAWAY
# 2561      241                4  Q4 00:04   REF_TIMEOUT_DISCUSSION???
# 2562      241                4        NaN            D_PENALTY_ON_US
# 2563      241                4        NaN                  GAME_OVER
#
#                                                  player      x      y  \
# 0                                                   NaN    NaN    NaN
# 1     Grayson Sanner, David Richardson, Justin Allen...    NaN    NaN
# 2                                     Rick Hennighausen  -6.89  91.56
# 3                                                   NaN    NaN    NaN
# 4     Alex Davis, Jacob Fairfax, Matt Gouchoe-Hanas,...    NaN    NaN
# ...                                                 ...    ...    ...
# 2559                                   Khalif El-Salaam -20.04  37.20
# 2560                                                NaN  -0.44  96.91
# 2561                                                NaN    NaN    NaN
# 2562                                                NaN    NaN    NaN
# 2563                                                NaN    NaN    NaN
#
#       o_point  d_point                                               line  \
# 0       False    False
# 1       False     True  [Grayson Sanner, David Richardson, Justin Alle...
# 2       False     True
# 3       False     True
# 4        True    False  [Alex Davis, Jacob Fairfax, Matt Gouchoe-Hanas...
# ...       ...      ...                                                ...
# 2559     True    False
# 2560     True    False
# 2561     True    False
# 2562     True    False
# 2563     True    False
#
#                                                reciever  turn  who_turned
# 0     Grayson Sanner, David Richardson, Justin Allen...   0.0         0.0
# 1                                     Rick Hennighausen   0.0         0.0
# 2                                                   NaN   0.0         0.0
# 3     Alex Davis, Jacob Fairfax, Matt Gouchoe-Hanas,...   0.0         0.0
# 4                                    Matt Gouchoe-Hanas   0.0         0.0
# ...                                                 ...   ...         ...
# 2559                                                NaN   0.0         1.0
# 2560                                                NaN   1.0         0.0
# 2561                                                NaN   0.0         0.0
# 2562                                                NaN   0.0         0.0
# 2563                                                NaN   0.0         NaN
#
# [2564 rows x 19 columns]

# %%
df.loc[df['who_turned'] > 0]
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 53             53     2894  2022-05-14        242        245             53
# 60             60     2894  2022-05-14        242        245             60
# 74             74     2894  2022-05-14        242        245             74
# 125           125     2894  2022-05-14        242        245            125
# 259           259     2894  2022-05-14        242        245            259
# ...           ...      ...         ...        ...        ...            ...
# 2396          280     2893  2022-04-29        242        241            280
# 2405          289     2893  2022-04-29        242        241            289
# 2512          396     2893  2022-04-29        242        241            396
# 2518          402     2893  2022-04-29        242        241            402
# 2559          443     2893  2022-04-29        242        241            443
#
#       team_id  current_quarter time         event_type             player  \
# 53        242                1  NaN         POSSESSION   Matthew Mcknight
# 60        242                1  NaN         POSSESSION      Dylan Hawkins
# 74        242                1  NaN         POSSESSION  Andrew Vande Berg
# 125       242                2  NaN         POSSESSION  Terrence Mitchell
# 259       242                3  NaN         POSSESSION   Matthew Mcknight
# ...       ...              ...  ...                ...                ...
# 2396      241                3  NaN         POSSESSION   Khalif El-Salaam
# 2405      241                3  NaN  D_PENALTY_ON_THEM                NaN
# 2512      241                4  NaN    O_PENALTY_ON_US                NaN
# 2518      241                4  NaN         POSSESSION  Bradley Seuntjens
# 2559      241                4  NaN         POSSESSION   Khalif El-Salaam
#
#           x      y  o_point  d_point line reciever  turn  who_turned
# 53     9.07  49.77     True    False           NaN   0.0         1.0
# 60    23.39  50.65     True    False           NaN   0.0         1.0
# 74    -9.48  56.86    False     True           NaN   0.0         1.0
# 125   21.75  57.00     True    False           NaN   0.0         1.0
# 259   17.59  50.31     True    False           NaN   0.0         1.0
# ...     ...    ...      ...      ...  ...      ...   ...         ...
# 2396  -8.97  73.03    False     True           NaN   0.0         1.0
# 2405    NaN    NaN    False     True           NaN   0.0         1.0
# 2512    NaN    NaN     True    False           NaN   0.0         1.0
# 2518  -1.03  41.50     True    False           NaN   0.0         1.0
# 2559 -20.04  37.20     True    False           NaN   0.0         1.0
#
# [90 rows x 19 columns]

# %%
df2 = df.loc[~df['event_type'].isin(pens)].copy()
# df2['turn'] = np.where(df2['event_type'].isin(turnovers), 1, 0)
# df2['who_turned'] = df2['turn'].shift(-1)

# %%
df2.loc[(df2['who_turned'] > 0) | (df2['turn'] > 0)]
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 53             53     2894  2022-05-14        242        245             53
# 54             54     2894  2022-05-14        242        245             54
# 60             60     2894  2022-05-14        242        245             60
# 61             61     2894  2022-05-14        242        245             61
# 74             74     2894  2022-05-14        242        245             74
# ...           ...      ...         ...        ...        ...            ...
# 2513          397     2893  2022-04-29        242        241            397
# 2518          402     2893  2022-04-29        242        241            402
# 2519          403     2893  2022-04-29        242        241            403
# 2559          443     2893  2022-04-29        242        241            443
# 2560          444     2893  2022-04-29        242        241            444
#
#       team_id  current_quarter time  event_type             player      x  \
# 53        242                1  NaN  POSSESSION   Matthew Mcknight   9.07
# 54        242                1  NaN   THROWAWAY                NaN -22.72
# 60        242                1  NaN  POSSESSION      Dylan Hawkins  23.39
# 61        242                1  NaN   THROWAWAY                NaN   6.61
# 74        242                1  NaN  POSSESSION  Andrew Vande Berg  -9.48
# ...       ...              ...  ...         ...                ...    ...
# 2513      241                4  NaN   THROWAWAY                NaN  -0.22
# 2518      241                4  NaN  POSSESSION  Bradley Seuntjens  -1.03
# 2519      241                4  NaN       STALL                NaN    NaN
# 2559      241                4  NaN  POSSESSION   Khalif El-Salaam -20.04
# 2560      241                4  NaN   THROWAWAY                NaN  -0.44
#
#            y  o_point  d_point line reciever  turn  who_turned
# 53     49.77     True    False           NaN   0.0         1.0
# 54    107.31     True    False           NaN   1.0         0.0
# 60     50.65     True    False           NaN   0.0         1.0
# 61     90.40     True    False           NaN   1.0         0.0
# 74     56.86    False     True           NaN   0.0         1.0
# ...      ...      ...      ...  ...      ...   ...         ...
# 2513   28.44     True    False           NaN   1.0         0.0
# 2518   41.50     True    False           NaN   0.0         1.0
# 2519     NaN     True    False           NaN   1.0         0.0
# 2559   37.20     True    False           NaN   0.0         1.0
# 2560   96.91     True    False           NaN   1.0         0.0
#
# [176 rows x 19 columns]

# %%
df2.loc[df2['event_type'] == "DROP"]
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 402           402     2894  2022-05-14        242        245            402
# 494            53     2894  2022-05-14        242        245             53
# 735           294     2894  2022-05-14        242        245            294
# 776           335     2894  2022-05-14        242        245            335
# 937            45     2905  2022-05-07        245        242             45
# 1223          331     2905  2022-05-07        245        242            331
# 1277          385     2905  2022-05-07        245        242            385
# 1430           77     2905  2022-05-07        245        242             77
# 1982          270     2893  2022-04-29        242        241            270
#
#       team_id  current_quarter time event_type         player      x       y  \
# 402       242                4  NaN       DROP     Alex Davis  14.04   54.81
# 494       245                1  NaN       DROP     Jacob Lane -12.90   53.11
# 735       245                3  NaN       DROP   Carl Johnson -10.24   54.20
# 776       245                3  NaN       DROP  Matt McDonald  14.66   39.81
# 937       245                1  NaN       DROP     Jacob Lane -22.92   78.00
# 1223      245                3  NaN       DROP  Tannon Hedges   7.70   70.02
# 1277      245                4  NaN       DROP  Robert Alongi  -8.73  106.15
# 1430      242                2  NaN       DROP  Jacob Fairfax  24.41  107.52
# 1982      242                3  NaN       DROP   Trevor Lynch   2.45   57.47
#
#       o_point  d_point line       reciever  turn  who_turned
# 402      True    False                 NaN   1.0         0.0
# 494      True    False                 NaN   1.0         0.0
# 735      True    False                 NaN   1.0         0.0
# 776      True    False       Matt McDonald   1.0         0.0
# 937     False     True                 NaN   1.0         0.0
# 1223    False     True         Tim Lootens   1.0         0.0
# 1277    False     True                 NaN   1.0         0.0
# 1430     True    False                 NaN   1.0         0.0
# 1982     True    False                 NaN   1.0         0.0

# %%
df2.loc[(df2['game_id'] == 2893) & (df2['event_index'] > 265)]
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 1978          266     2893  2022-04-29        242        241            266
# 1979          267     2893  2022-04-29        242        241            267
# 1980          268     2893  2022-04-29        242        241            268
# 1981          269     2893  2022-04-29        242        241            269
# 1982          270     2893  2022-04-29        242        241            270
# ...           ...      ...         ...        ...        ...            ...
# 2558          442     2893  2022-04-29        242        241            442
# 2559          443     2893  2022-04-29        242        241            443
# 2560          444     2893  2022-04-29        242        241            444
# 2561          445     2893  2022-04-29        242        241            445
# 2563          447     2893  2022-04-29        242        241            447
#
#       team_id  current_quarter       time                 event_type  \
# 1978      242                3        NaN                 POSSESSION
# 1979      242                3  Q3 03:19        OUR_MIDPOINT_TIMEOUT
# 1980      242                3        NaN         SET_O_LINE_NO_PULL
# 1981      242                3        NaN                 POSSESSION
# 1982      242                3        NaN                       DROP
# ...       ...              ...        ...                        ...
# 2558      241                4        NaN                 POSSESSION
# 2559      241                4        NaN                 POSSESSION
# 2560      241                4        NaN                  THROWAWAY
# 2561      241                4  Q4 00:04   REF_TIMEOUT_DISCUSSION???
# 2563      241                4        NaN                  GAME_OVER
#
#                                                  player      x      y  \
# 1978                                     Tim McAllister  19.50  42.27
# 1979                                                NaN    NaN    NaN
# 1980  Jacob Fairfax, Henry Fisher, Matt Gouchoe-Hana...    NaN    NaN
# 1981                                         Sol Yanuck  19.50  42.27
# 1982                                       Trevor Lynch   2.45  57.47
# ...                                                 ...    ...    ...
# 2558                                      Austin Taylor  -2.92  26.65
# 2559                                   Khalif El-Salaam -20.04  37.20
# 2560                                                NaN  -0.44  96.91
# 2561                                                NaN    NaN    NaN
# 2563                                                NaN    NaN    NaN
#
#       o_point  d_point                                               line  \
# 1978     True    False
# 1979     True    False
# 1980     True    False  [Jacob Fairfax, Henry Fisher, Matt Gouchoe-Han...
# 1981     True    False
# 1982     True    False
# ...       ...      ...                                                ...
# 2558     True    False
# 2559     True    False
# 2560     True    False
# 2561     True    False
# 2563     True    False
#
#                                                reciever  turn  who_turned
# 1978                                                NaN   0.0         0.0
# 1979  Jacob Fairfax, Henry Fisher, Matt Gouchoe-Hana...   0.0         0.0
# 1980                                         Sol Yanuck   0.0         0.0
# 1981                                       Trevor Lynch   0.0         0.5
# 1982                                                NaN   1.0         0.0
# ...                                                 ...   ...         ...
# 2558                                   Khalif El-Salaam   0.0         0.0
# 2559                                                NaN   0.0         1.0
# 2560                                                NaN   1.0         0.0
# 2561                                                NaN   0.0         0.0
# 2563                                                NaN   0.0         NaN
#
# [295 rows x 19 columns]
