# %% [markdown]
# # Lines Analysis

# %% [markdown]
# ## Import

# %%
import os

import numpy as np
import pandas as pd

import janitor

# %% [markdown]
# ## Constants

# %%
scores = ['GOAL', 'SCORED_ON', 'CALLAHAN', 'CALLAHAN_THROWN']
we_score = ['GOAL', 'CALLAHAN']
they_score = ['SCORED_ON', 'CALLAHAN_THROWN']

turnovers = ['THROWAWAY', 'DROP', 'STALL', 'CALLAHAN_THROWN']
takeaways = ['BLOCK', 'CALLAHAN', 'STALL_CAUSED', 'THROWAWAY_CAUSED']

pulls = ['PULL_OUT_OF_BOUNDS', 'PULL_INBOUNDS']

pens = ['D_PENALTY_ON_THEM', 'D_PENALTY_ON_US', 'O_PENALTY_ON_THEM', 'O_PENALTY_ON_US']

quarter_ends = ['START_OF_GAME', 'END_OF_Q1', 'HALFTIME', 'END_OF_Q3', 'GAME_OVER']

line_sets = ['SET_D_LINE', 'SET_O_LINE', 'SET_D_LINE_NO_PULL', 'SET_O_LINE_NO_PULL']
o_lines = ['SET_O_LINE', 'SET_O_LINE_NO_PULL']
d_lines = ['SET_D_LINE', 'SET_D_LINE_NO_PULL']

timeouts = ['THEIR_MIDPOINT_TIMEOUT', 'OUR_MIDPOINT_TIMEOUT']

other = ['REF_TIMEOUT_DISCUSSION???', 'INJURY_ON_O', 'INJURY_ON_D']

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### File IO

# %%
df = pd.read_csv("Flyers_Games.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)
df_home = pd.read_csv("Flyers_Games_home.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)
df_away = pd.read_csv("Flyers_Games_away.csv").rename({"Unnamed: 0" : "event_index"}, axis=1)

# %%
df.head(35)
# Out:
#     event_index  game_id        date  home_team  away_team  event_counter  \
# 0             0     2908  2022-06-25        245        242              0
# 1             1     2908  2022-06-25        245        242              1
# 2             2     2908  2022-06-25        245        242              2
# 3             3     2908  2022-06-25        245        242              3
# 4             4     2908  2022-06-25        245        242              4
# 5             5     2908  2022-06-25        245        242              5
# 6             6     2908  2022-06-25        245        242              6
# 7             7     2908  2022-06-25        245        242              7
# 8             8     2908  2022-06-25        245        242              8
# 9             9     2908  2022-06-25        245        242              9
# 10           10     2908  2022-06-25        245        242             10
# 11           11     2908  2022-06-25        245        242             11
# 12           12     2908  2022-06-25        245        242             12
# 13           13     2908  2022-06-25        245        242             13
# 14           14     2908  2022-06-25        245        242             14
# 15           15     2908  2022-06-25        245        242             15
# 16           16     2908  2022-06-25        245        242             16
# 17           17     2908  2022-06-25        245        242             17
# 18           18     2908  2022-06-25        245        242             18
# 19           19     2908  2022-06-25        245        242             19
# 20           20     2908  2022-06-25        245        242             20
# 21           21     2908  2022-06-25        245        242             21
# 22           22     2908  2022-06-25        245        242             22
# 23           23     2908  2022-06-25        245        242             23
# 24           24     2908  2022-06-25        245        242             24
# 25           25     2908  2022-06-25        245        242             25
# 26           26     2908  2022-06-25        245        242             26
# 27           27     2908  2022-06-25        245        242             27
# 28           28     2908  2022-06-25        245        242             28
# 29           29     2908  2022-06-25        245        242             29
# 30           30     2908  2022-06-25        245        242             30
# 31           31     2908  2022-06-25        245        242             31
# 32           32     2908  2022-06-25        245        242             32
# 33           33     2908  2022-06-25        245        242             33
# 34           34     2908  2022-06-25        245        242             34
#
#     team_id  current_quarter       time     event_type  \
# 0       245              1.0        NaN  START_OF_GAME
# 1       245              1.0        NaN     SET_D_LINE
# 2       245              1.0        NaN  PULL_INBOUNDS
# 3       245              1.0        NaN          BLOCK
# 4       245              1.0        NaN     POSSESSION
# 5       245              1.0        NaN     POSSESSION
# 6       245              1.0        NaN           DROP
# 7       245              1.0  Q1 11:10       SCORED_ON
# 8       245              1.0        NaN     SET_O_LINE
# 9       245              1.0        NaN     POSSESSION
# 10      245              1.0        NaN     POSSESSION
# 11      245              1.0        NaN     POSSESSION
# 12      245              1.0        NaN     POSSESSION
# 13      245              1.0        NaN     POSSESSION
# 14      245              1.0        NaN     POSSESSION
# 15      245              1.0        NaN     POSSESSION
# 16      245              1.0        NaN     POSSESSION
# 17      245              1.0        NaN     POSSESSION
# 18      245              1.0        NaN     POSSESSION
# 19      245              1.0        NaN     POSSESSION
# 20      245              1.0        NaN           DROP
# 21      245              1.0        NaN          BLOCK
# 22      245              1.0        NaN     POSSESSION
# 23      245              1.0        NaN      THROWAWAY
# 24      245              1.0        NaN          BLOCK
# 25      245              1.0        NaN     POSSESSION
# 26      245              1.0        NaN      THROWAWAY
# 27      245              1.0  Q1 08:06       SCORED_ON
# 28      245              1.0        NaN     SET_O_LINE
# 29      245              1.0        NaN     POSSESSION
# 30      245              1.0        NaN     POSSESSION
# 31      245              1.0        NaN     POSSESSION
# 32      245              1.0        NaN     POSSESSION
# 33      245              1.0        NaN     POSSESSION
# 34      245              1.0        NaN     POSSESSION
#
#                                                player      x      y  o_point  \
# 0                                                 NaN    NaN    NaN    False
# 1   Michael Arbutine, Cody Coates, Garrett Knobel,...    NaN    NaN    False
# 2                                    Michael Arbutine   7.57  80.31    False
# 3                                    Michael Arbutine    NaN    NaN    False
# 4                                    Michael Arbutine  -0.48  39.95    False
# 5                                       Sean Plunkett   7.36  44.31    False
# 6                                     Clayton Partlow  22.91  60.61    False
# 7                                                 NaN    NaN    NaN    False
# 8   Tannon Hedges, Carl Johnson, Billy O'Bryan, Un...    NaN    NaN     True
# 9                                       Tannon Hedges   0.00  40.00     True
# 10                                        Jaime Perez  -4.78  32.72     True
# 11                                      Tannon Hedges   2.52  31.84     True
# 12                                        Adam Vinson  16.09  29.93     True
# 13                                       Carl Johnson  21.41  45.47     True
# 14                                        Unmil Patel  21.34  56.31     True
# 15                                      Billy O'Bryan   8.66  54.06     True
# 16                                      Jorge Delgado -13.17  56.11     True
# 17                                      Tannon Hedges  -1.78  63.40     True
# 18                                        Adam Vinson  19.16  66.75     True
# 19                                        Unmil Patel  14.93  80.93     True
# 20                                      Billy O'Bryan  18.14  88.09     True
# 21                                        Jaime Perez    NaN    NaN     True
# 22                                      Tannon Hedges -14.26  65.65     True
# 23                                                NaN -14.26  65.65     True
# 24                                      Jorge Delgado    NaN    NaN     True
# 25                                      Billy O'Bryan -13.78  62.86     True
# 26                                                NaN -13.78  62.86     True
# 27                                                NaN    NaN    NaN     True
# 28  Billy O'Bryan, Logan Diehl , Sean Plunkett, Au...    NaN    NaN     True
# 29                                      Austin Gaines  15.00  39.61     True
# 30                                       Logan Diehl    5.86  46.02     True
# 31                                       Tyler Hebert  -6.42  52.02     True
# 32                                      Sean Plunkett -17.60  57.40     True
# 33                                         Ryan Hiser  -9.89  62.31     True
# 34                                       Tyler Hebert   0.61  59.72     True
#
#     d_point  point_id  our_score  their_score  \
# 0     False         0          0            0
# 1      True         1          0            0
# 2      True         1          0            0
# 3      True         1          0            0
# 4      True         1          0            0
# 5      True         1          0            0
# 6      True         1          0            0
# 7      True         1          0            1
# 8     False         2          0            1
# 9     False         2          0            1
# 10    False         2          0            1
# 11    False         2          0            1
# 12    False         2          0            1
# 13    False         2          0            1
# 14    False         2          0            1
# 15    False         2          0            1
# 16    False         2          0            1
# 17    False         2          0            1
# 18    False         2          0            1
# 19    False         2          0            1
# 20    False         2          0            1
# 21    False         2          0            1
# 22    False         2          0            1
# 23    False         2          0            1
# 24    False         2          0            1
# 25    False         2          0            1
# 26    False         2          0            1
# 27    False         2          0            2
# 28    False         3          0            2
# 29    False         3          0            2
# 30    False         3          0            2
# 31    False         3          0            2
# 32    False         3          0            2
# 33    False         3          0            2
# 34    False         3          0            2
#
#                                                  line
# 0                                                 NaN
# 1   ['Michael Arbutine', 'Cody Coates', 'Garrett K...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   ['Tannon Hedges', 'Carl Johnson', "Billy O'Bry...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  ["Billy O'Bryan", 'Logan Diehl ', 'Sean Plunke...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN

# %% [markdown]
# ### Cleaning

# %%
df['is_home'] = df['home_team'] == df['team_id']
df['is_away'] = df['away_team'] == df['team_id']

df["game_point_id"] = df["game_id"]*1000 + df["point_id"]

df['player'] = np.where(df['event_type'].isin(line_sets), df['player'], "")

df['home_score']  = np.where((df['is_home']) & (df['event_type'].isin(we_score)), 1, 0)
df['away_score']  = np.where((df['is_away']) & (df['event_type'].isin(we_score)), 1, 0)

# %% [markdown]
# ### LINES

# %%
all_lines = df.loc[df['event_type'].isin(line_sets)].copy()

# How many lines are there per point
all_lines['line_number_in_point'] = all_lines.groupby('game_point_id')['event_counter'].cumcount()
print("Max Number of Lines in a point:", all_lines['line_number_in_point'].unique().max())

# Make Line ID within point within game
# Multiply by 10 is safe
all_lines['game_point_line_id'] = all_lines['game_point_id']*10 + all_lines['line_number_in_point']
# Out:
# Max Number of Lines in a point: 7

# %%
all_lines.columns
# Out:
# Index(['event_index', 'game_id', 'date', 'home_team', 'away_team',
#        'event_counter', 'team_id', 'current_quarter', 'time', 'event_type',
#        'player', 'x', 'y', 'o_point', 'd_point', 'point_id', 'our_score',
#        'their_score', 'line', 'is_home', 'is_away', 'game_point_id',
#        'home_score', 'away_score', 'line_number_in_point',
#        'game_point_line_id'],
#       dtype='object')

# %% [raw]
# [x.strip() for x in all_lines['player'].iloc[0].split(",")]
#
# all_lines['player2'] = all_lines['player'].str.split(",")
#
# all_lines['player3'] = [[x.strip() for x in y] for y in all_lines['player2']]
#
# all_lines['player4'].iloc[0]

# %%
# Players in each line
all_lines['line_players_original'] = [[x.strip() for x in y[:-1]] for y in all_lines['player'].str.split(",")]
all_lines['line_players'] = all_lines['line_players_original'].apply(lambda x: sorted(x))

all_lines['line_players'].value_counts()
# Out:
# [Evan Swiatek, Jake Radack, Kyle Henke, Mark Evans, Paul Starkel, Reese Bowman, Vinay Valsaraj]                         50
# [Alex Davis, Eric Taylor, Grayson Sanner, Henry Fisher, Jacob Fairfax, Matt Gouchoe-Hanas, Sol Yanuck]                  26
# [Ben Lewis, Brandon Malecek, Carson Wilder, Jimmy Zuraw, Kevin Richardson, Michael Matthis, Rory Orloff]                20
# [Alex Davis, Anders Juengst, Henry Fisher, Jacob Fairfax, Noah Saul, Sol Yanuck, Terrence Mitchell]                     18
# [Ben Lewis, Brooks Wallace, Carson Wilder, Emmanuel Bilolo, Kevin Richardson, Michael Matthis, Rory Orloff]             17
#                                                                                                                         ..
# [Alex Cloud, Andrew Vande Berg, Elijah Long, Grayson Sanner, Justin Allen, Marc Rovner, Rick Hennighausen]               1
# [Alex Davis, David Richardson, Dylan Hawkins, Jacob Fairfax, Rick Hennighausen, Suraj Madiraju, William Coffin]          1
# [Andrew Vande Berg, Charlie McCutcheon, Grayson Sanner, Marc Rovner, Michael Lee, Rick Hennighausen, Suraj Madiraju]     1
# [Charlie McCutcheon, David Richardson, Elijah Long, Grayson Sanner, Justin Allen, Suraj Madiraju, William Coffin]        1
# [Austin Taylor, Bradley Seuntjens, Elijah Jaime, Karl Ekwurtzel, Khalif El-Salaam, Matt Smith, Sam Gabrielson]           1
# Name: line_players, Length: 438, dtype: int64

# %%
# ID for each unique line
deduped_lines = all_lines['line_players'].drop_duplicates()
deduped_idx = deduped_lines.index

df_line_ids = pd.concat([all_lines.loc[deduped_idx, 'team_id'], deduped_lines], axis=1).reset_index(drop=True)
df_line_ids['line_id'] = df['team_id']*10000 + df_line_ids.groupby('team_id')['line_players'].transform('cumcount')
df_line_ids['line_id'] = df_line_ids['line_id'].astype(int)
df_line_ids
# Out:
#      team_id                                       line_players  line_id
# 0        245  [Clayton Partlow, Cody Coates, David Witte, Ga...  2450000
# 1        245  [Adam Vinson, Billy O'Bryan, Carl Johnson, Jai...  2450001
# 2        245  [Austin Gaines, Billy O'Bryan, Logan Diehl, Ry...  2450002
# 3        245  [Anish Indhupuru, Clayton Partlow, Cody Coates...  2450003
# 4        245  [Adam Vinson, Anish Indhupuru, Billy O'Bryan, ...  2450004
# ..       ...                                                ...      ...
# 433      241  [Austin Taylor, Bradley Seuntjens, Christian O...  2410060
# 434      241  [Austin Taylor, Bradley Seuntjens, Eli Motycka...  2410061
# 435      241  [Austin Taylor, Bradley Seuntjens, Christian O...  2410062
# 436      241  [Austin Taylor, Christian Olsen, Dean Ramsey, ...  2410063
# 437      241  [Austin Taylor, Bradley Seuntjens, Elijah Jaim...  2410064
#
# [438 rows x 3 columns]

# %%
# Need to get line ids
df_line_sets = all_lines.loc[:, ['team_id', 'game_id', 'line_players']]

# result = df.a.sort_values().apply(lambda x: sorted(x))

df_line_sets['sorted_line_players'] = df_line_sets['line_players'].apply(lambda x: sorted(x))
split_series = df_line_sets.sorted_line_players.apply(lambda x:pd.Series(str(x).replace("[", "").replace("]", "").split(",")))
print(split_series.shape)
split_series.drop_duplicates()

# ser = pd.get_dummies(df_line_sets['line_players'])
# Out:
# (885, 7)
#                       0                     1                   2  \
# 1     'Clayton Partlow'         'Cody Coates'       'David Witte'
# 8         'Adam Vinson'       "Billy O'Bryan"      'Carl Johnson'
# 28      'Austin Gaines'       "Billy O'Bryan"       'Logan Diehl'
# 38    'Anish Indhupuru'     'Clayton Partlow'       'Cody Coates'
# 42        'Adam Vinson'     'Anish Indhupuru'     "Billy O'Bryan"
# ...                 ...                   ...                 ...
# 7877    'Austin Taylor'   'Bradley Seuntjens'   'Christian Olsen'
# 7900    'Austin Taylor'   'Bradley Seuntjens'       'Eli Motycka'
# 7911    'Austin Taylor'   'Bradley Seuntjens'   'Christian Olsen'
# 7947    'Austin Taylor'     'Christian Olsen'       'Dean Ramsey'
# 7952    'Austin Taylor'   'Bradley Seuntjens'      'Elijah Jaime'
#
#                       3                    4                    5  \
# 1      'Garrett Knobel'   'Michael Arbutine'      'Sean Plunkett'
# 8         'Jaime Perez'      'Jorge Delgado'      'Tannon Hedges'
# 28         'Ryan Hiser'      'Sean Plunkett'        'Tim Lootens'
# 38        'David Witte'     'Garrett Knobel'   'Michael Arbutine'
# 42       'Carl Johnson'        'Jaime Perez'      'Tannon Hedges'
# ...                 ...                  ...                  ...
# 7877         'JP Burns'     'Karl Ekwurtzel'         'Matt Smith'
# 7900     'Elijah Jaime'           'JP Burns'         'Matt Smith'
# 7911     'Elijah Jaime'     'Karl Ekwurtzel'   'Khalif El-Salaam'
# 7947         'JP Burns'    'Kelvin Williams'   'Khalif El-Salaam'
# 7952   'Karl Ekwurtzel'   'Khalif El-Salaam'         'Matt Smith'
#
#                        6
# 1          'Tim Lootens'
# 8          'Unmil Patel'
# 28        'Tyler Hebert'
# 38       'Sean Plunkett'
# 42         'Unmil Patel'
# ...                  ...
# 7877    'Sam Gabrielson'
# 7900    'Sam Gabrielson'
# 7911        'Matt Smith'
# 7947   'Tanner Robinson'
# 7952    'Sam Gabrielson'
#
# [438 rows x 7 columns]

# %%
# Last Line on for each point
last_line_by_point_idx = all_lines.groupby(['game_point_id', 'team_id'], sort=False)['game_point_line_id'].transform('max') == all_lines['game_point_line_id']
last_lines = all_lines.loc[last_line_by_point_idx].sort_values('game_point_id')
# last_lines.sort_values(['game_point_id', 'game_point_line_id']).head(5)

all_lines = all_lines.merge(last_lines.loc[:, 'game_point_line_id'], how='left', on='game_point_line_id', indicator=True)
all_lines['is_last_line'] = all_lines['_merge'] == 'both'
del all_lines['_merge']

# %%
home_lines = all_lines.loc[all_lines['is_home'] == True].copy()
away_lines = all_lines.loc[all_lines['is_home'] == False].copy()

# %%
all_lines.columns
# Out:
# Index(['event_index', 'game_id', 'date', 'home_team', 'away_team',
#        'event_counter', 'team_id', 'current_quarter', 'time', 'event_type',
#        'player', 'x', 'y', 'o_point', 'd_point', 'point_id', 'our_score',
#        'their_score', 'line', 'is_home', 'is_away', 'game_point_id',
#        'home_score', 'away_score', 'line_number_in_point',
#        'game_point_line_id', 'line_players_original', 'line_players',
#        'is_last_line'],
#       dtype='object')

# %%
keep_cols_a = [
    'date', 'game_id', 'game_point_id', 'game_point_line_id', 
    'home_team', 'away_team', 'team_id', 'current_quarter',
    'event_type', 'o_point', 'd_point', 'point_id',
    'our_score', 'their_score', 'is_home', 'is_away', 'line_players',
    'is_last_line', 'line_number_in_point'
]

keep_cols_b = ['game_point_id', 'game_point_line_id', 'team_id', 'line_players', 'event_type', 'is_last_line']

rename_cols_a = {
    'team_id': 'team_id_a',
    'is_home': 'is_home_a',
    'is_away': 'is_away_a',
    'game_point_line_id': 'line_id_a',
    'line_players': 'line_players_a',
    'is_last_line': 'is_last_line_a',
    'our_score': 'our_score_point_start',
    'their_score': 'their_score_point_start',
    'event_type': 'line_set_type_a',
    'o_point': 'o_point_a'
}

rename_cols_b = {
    'team_id': 'team_id_b',
    'game_point_line_id': 'line_id_b',
    'line_players': 'line_players_b',
    'is_last_line': 'is_last_line_b',
    'event_type': 'line_set_type_b',
}

final_lines = home_lines.loc[:, keep_cols_a].rename(rename_cols_a, axis=1).merge(
    away_lines.loc[:, keep_cols_b].rename(rename_cols_b, axis=1),
    how='outer',
    on='game_point_id',
    indicator=True,
    copy=True
)
del final_lines['_merge']
print(final_lines.shape)
final_lines.head()
# Out:
# (568, 24)
#          date  game_id  game_point_id  line_id_a  home_team  away_team  \
# 0  2022-06-25     2908        2908001   29080010        245        242
# 1  2022-06-25     2908        2908002   29080020        245        242
# 2  2022-06-25     2908        2908003   29080030        245        242
# 3  2022-06-25     2908        2908004   29080040        245        242
# 4  2022-06-25     2908        2908004   29080040        245        242
#
#    team_id_a  current_quarter line_set_type_a  o_point_a  ...  is_home_a  \
# 0        245              1.0      SET_D_LINE      False  ...       True
# 1        245              1.0      SET_O_LINE       True  ...       True
# 2        245              1.0      SET_O_LINE       True  ...       True
# 3        245              1.0      SET_D_LINE      False  ...       True
# 4        245              1.0      SET_D_LINE      False  ...       True
#
#    is_away_a                                     line_players_a  \
# 0      False  [Clayton Partlow, Cody Coates, David Witte, Ga...
# 1      False  [Adam Vinson, Billy O'Bryan, Carl Johnson, Jai...
# 2      False  [Austin Gaines, Billy O'Bryan, Logan Diehl, Ry...
# 3      False  [Anish Indhupuru, Clayton Partlow, Cody Coates...
# 4      False  [Anish Indhupuru, Clayton Partlow, Cody Coates...
#
#    is_last_line_a  line_number_in_point  line_id_b team_id_b  \
# 0            True                     0   29080011       242
# 1            True                     0   29080021       242
# 2            True                     0   29080031       242
# 3           False                     0   29080042       242
# 4           False                     0   29080043       242
#
#                                       line_players_b     line_set_type_b  \
# 0  [Alex Davis, Elijah Long, Eric Taylor, Henry F...          SET_O_LINE
# 1  [Andrew Li, Andrew McKelvey, Charlie McCutcheo...          SET_D_LINE
# 2  [Alex Cloud, Charlie McCutcheon, Dylan Hawkins...          SET_D_LINE
# 3  [Alex Davis, Elijah Long, Eric Taylor, Henry F...          SET_O_LINE
# 4  [Andrew McKelvey, Charlie McCutcheon, David Ri...  SET_D_LINE_NO_PULL
#
#    is_last_line_b
# 0            True
# 1            True
# 2            True
# 3           False
# 4            True
#
# [5 rows x 24 columns]

# %%
df_quarter_ends = df.loc[(df['event_type'].isin(quarter_ends))].copy()
df_quarter_ends.shape
df_quarter_ends.head()
# Out:
#      event_index  game_id        date  home_team  away_team  event_counter  \
# 0              0     2908  2022-06-25        245        242              0
# 110          110     2908  2022-06-25        245        242            110
# 227          227     2908  2022-06-25        245        242            227
# 324          324     2908  2022-06-25        245        242            324
# 422          422     2908  2022-06-25        245        242            422
#
#      team_id  current_quarter time     event_type  ... d_point  point_id  \
# 0        245              1.0  NaN  START_OF_GAME  ...   False         0
# 110      245              2.0  NaN      END_OF_Q1  ...    True         9
# 227      245              3.0  NaN       HALFTIME  ...   False        19
# 324      245              4.0  NaN      END_OF_Q3  ...    True        27
# 422      245              4.0  NaN      GAME_OVER  ...   False        42
#
#      our_score  their_score  line  is_home  is_away  game_point_id home_score  \
# 0            0            0   NaN     True    False        2908000          0
# 110          3            5   NaN     True    False        2908009          0
# 227          6           11   NaN     True    False        2908019          0
# 324          9           15   NaN     True    False        2908027          0
# 422         15           23   NaN     True    False        2908042          0
#
#      away_score
# 0             0
# 110           0
# 227           0
# 324           0
# 422           0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### POINTS

# %%
df_scores = df.loc[(df['event_type'].isin(we_score))].copy()

df_scores['scoring_team'] = df_scores['team_id']
# df_scores = df.loc[(df['event_type'] == 'GOAL') | (df['event_type'] == 'CALLAHAN')].copy()
df_scores.sort_values('game_point_id').head(10)
# Out:
#       event_index  game_id        date  home_team  away_team  event_counter  \
# 438            15     2884  2022-06-17        241        242             15
# 4356           17     2884  2022-06-17        241        242             17
# 453            30     2884  2022-06-17        241        242             30
# 459            36     2884  2022-06-17        241        242             36
# 4387           48     2884  2022-06-17        241        242             48
# 4397           58     2884  2022-06-17        241        242             58
# 476            53     2884  2022-06-17        241        242             53
# 4436           97     2884  2022-06-17        241        242             97
# 4442          103     2884  2022-06-17        241        242            103
# 508            85     2884  2022-06-17        241        242             85
#
#       team_id  current_quarter       time event_type  ... point_id  our_score  \
# 438       241              1.0  Q1 10:55        GOAL  ...        1          1
# 4356      242              1.0  Q1 10:07        GOAL  ...        2          1
# 453       241              1.0  Q1 09:18        GOAL  ...        3          2
# 459       241              1.0  Q1 08:29        GOAL  ...        4          3
# 4387      242              1.0  Q1 07:45        GOAL  ...        5          2
# 4397      242              1.0  Q1 07:03        GOAL  ...        6          3
# 476       241              1.0  Q1 06:35        GOAL  ...        7          4
# 4436      242              1.0  Q1 04:16        GOAL  ...        8          4
# 4442      242              1.0  Q1 03:37        GOAL  ...        9          5
# 508       241              1.0  Q1 02:58        GOAL  ...       10          5
#
#       their_score  line  is_home  is_away  game_point_id  home_score  \
# 438             0   NaN     True    False        2884001           1
# 4356            1   NaN    False     True        2884002           0
# 453             1   NaN     True    False        2884003           1
# 459             1   NaN     True    False        2884004           1
# 4387            3   NaN    False     True        2884005           0
# 4397            3   NaN    False     True        2884006           0
# 476             3   NaN     True    False        2884007           1
# 4436            4   NaN    False     True        2884008           0
# 4442            4   NaN    False     True        2884009           0
# 508             5   NaN     True    False        2884010           1
#
#      away_score  scoring_team
# 438           0           241
# 4356          1           242
# 453           0           241
# 459           0           241
# 4387          1           242
# 4397          1           242
# 476           0           241
# 4436          1           242
# 4442          1           242
# 508           0           241
#
# [10 rows x 25 columns]

# %%
df_scores.columns
# Out:
# Index(['event_index', 'game_id', 'date', 'home_team', 'away_team',
#        'event_counter', 'team_id', 'current_quarter', 'time', 'event_type',
#        'player', 'x', 'y', 'o_point', 'd_point', 'point_id', 'our_score',
#        'their_score', 'line', 'is_home', 'is_away', 'game_point_id',
#        'home_score', 'away_score', 'scoring_team'],
#       dtype='object')

# %%
score_keep_cols = [
     'game_point_id', 'time', 'event_type', 'o_point', 'is_home', 'is_away', 
    'our_score', 'their_score', 'scoring_team', 'home_score', 'away_score'
]

score_rename_cols = {
    'event_type': 'score_type',
    'time': 'time_of_score',
    'our_score': 'our_score_point_end',
    'their_score': 'their_score_point_end',
    'home_score': 'home_team_scored', 
    'away_score': 'away_team_scored'
}
final_scores = df_scores.loc[:, score_keep_cols].rename(score_rename_cols, axis=1).sort_values('game_point_id')

# %% [markdown]
# ### FINAL DF

# %%
df_final = final_lines.merge(
    final_scores,
    on='game_point_id',
    how='outer',
    indicator=True,
    copy=True
)

df_final.head(10)
df_final._merge.value_counts()
# Out:
# both          527
# left_only      41
# right_only      0
# Name: _merge, dtype: int64

# %% [raw]
# # Manual Checking the weird merges
# check = 14
#
# left_only_ids = list(df_final.loc[df_final['_merge'] == "left_only", 'game_point_id'].values)
# print(len(left_only_ids))
#
# df.loc[df['game_point_id'] == (left_only_ids[check])]

# %%
df_final.columns
# Out:
# Index(['date', 'game_id', 'game_point_id', 'line_id_a', 'home_team',
#        'away_team', 'team_id_a', 'current_quarter', 'line_set_type_a',
#        'o_point_a', 'd_point', 'point_id', 'our_score_point_start',
#        'their_score_point_start', 'is_home_a', 'is_away_a', 'line_players_a',
#        'is_last_line_a', 'line_number_in_point', 'line_id_b', 'team_id_b',
#        'line_players_b', 'line_set_type_b', 'is_last_line_b', 'time_of_score',
#        'score_type', 'o_point', 'is_home', 'is_away', 'our_score_point_end',
#        'their_score_point_end', 'scoring_team', 'home_team_scored',
#        'away_team_scored', '_merge'],
#       dtype='object')

# %%
df_final.loc[df_final['line_set_type_a'].str.contains("O_LINE"), ['game_point_id', 'home_team', 'away_team', 'team_id_a', 'o_point_a']]
# Out:
#      game_point_id  home_team  away_team  team_id_a  o_point_a
# 1          2908002        245        242        245       True
# 2          2908003        245        242        245       True
# 5          2908004        245        242        245      False
# 6          2908004        245        242        245      False
# 8          2908006        245        242        245       True
# ..             ...        ...        ...        ...        ...
# 557        2893027        242        241        242       True
# 559        2893029        242        241        242       True
# 563        2893031        242        241        242      False
# 564        2893031        242        241        242      False
# 566        2893033        242        241        242       True
#
# [293 rows x 5 columns]

# %%
cols = [
    'date', 'game_id', 'home_team', 'away_team', 'game_point_id', 
    'current_quarter', 'time_of_score',
    'team_id_a', 'line_id_a', 'line_players_a', 'line_set_type_a', 'is_last_line_a', 'is_home_a', 'o_point_a',
    'team_id_b', 'line_id_b', 'line_players_b', 'line_set_type_b', 'is_last_line_b',
    'our_score_point_start',
    'their_score_point_start', 'our_score_point_end', 'their_score_point_end',
    'home_team_scored', 'away_team_scored',
    'scoring_team', 'score_type'
]

final_rename = {
    'our_score_point_start': 'team_a_score_point_start',
    'their_score_point_start': 'team_b_score_point_start'
}

leftover = [x for x in df_final.columns if x not in cols]
leftover
# Out:
# ['d_point',
#  'point_id',
#  'is_away_a',
#  'line_number_in_point',
#  'o_point',
#  'is_home',
#  'is_away',
#  '_merge']

# %% [raw]
# df_final.iloc[35]

# %% [raw]
# df_final[['game_point_id', 'home_team', 'line_set_type_a',
#        'away_team', 'team_id_a','o_point_a', 'o_point']].head(10)

# %%
df_final['team_a_scored'] = (df_final['scoring_team'] == df_final['team_id_a']) & df_final['score_type'].notna()
df_final['team_b_scored'] = (df_final['scoring_team'] == df_final['team_id_b']) & df_final['score_type'].notna()

cols.remove('home_team_scored')
cols.remove('away_team_scored')
cols.remove('our_score_point_end')
cols.remove('their_score_point_end')

cols.append('team_a_scored')
cols.append('team_b_scored')
cols
# Out:
# ['date',
#  'game_id',
#  'home_team',
#  'away_team',
#  'game_point_id',
#  'current_quarter',
#  'time_of_score',
#  'team_id_a',
#  'line_id_a',
#  'line_players_a',
#  'line_set_type_a',
#  'is_last_line_a',
#  'is_home_a',
#  'o_point_a',
#  'team_id_b',
#  'line_id_b',
#  'line_players_b',
#  'line_set_type_b',
#  'is_last_line_b',
#  'our_score_point_start',
#  'their_score_point_start',
#  'scoring_team',
#  'score_type',
#  'team_a_scored',
#  'team_b_scored']

# %%
df_output = df_final.loc[:, cols].rename(final_rename, axis=1)
df_output.columns
# Out:
# Index(['date', 'game_id', 'home_team', 'away_team', 'game_point_id',
#        'current_quarter', 'time_of_score', 'team_id_a', 'line_id_a',
#        'line_players_a', 'line_set_type_a', 'is_last_line_a', 'is_home_a',
#        'o_point_a', 'team_id_b', 'line_id_b', 'line_players_b',
#        'line_set_type_b', 'is_last_line_b', 'team_a_score_point_start',
#        'team_b_score_point_start', 'scoring_team', 'score_type',
#        'team_a_scored', 'team_b_scored'],
#       dtype='object')

# %%
df_output.head()
# Out:
#          date  game_id  home_team  away_team  game_point_id  current_quarter  \
# 0  2022-06-25     2908        245        242        2908001              1.0
# 1  2022-06-25     2908        245        242        2908002              1.0
# 2  2022-06-25     2908        245        242        2908003              1.0
# 3  2022-06-25     2908        245        242        2908004              1.0
# 4  2022-06-25     2908        245        242        2908004              1.0
#
#   time_of_score  team_id_a  line_id_a  \
# 0     Q1 11:10         245   29080010
# 1     Q1 08:06         245   29080020
# 2     Q1 07:17         245   29080030
# 3     Q1 05:23         245   29080040
# 4     Q1 05:23         245   29080040
#
#                                       line_players_a  ... line_id_b  \
# 0  [Clayton Partlow, Cody Coates, David Witte, Ga...  ...  29080011
# 1  [Adam Vinson, Billy O'Bryan, Carl Johnson, Jai...  ...  29080021
# 2  [Austin Gaines, Billy O'Bryan, Logan Diehl, Ry...  ...  29080031
# 3  [Anish Indhupuru, Clayton Partlow, Cody Coates...  ...  29080042
# 4  [Anish Indhupuru, Clayton Partlow, Cody Coates...  ...  29080043
#
#                                       line_players_b     line_set_type_b  \
# 0  [Alex Davis, Elijah Long, Eric Taylor, Henry F...          SET_O_LINE
# 1  [Andrew Li, Andrew McKelvey, Charlie McCutcheo...          SET_D_LINE
# 2  [Alex Cloud, Charlie McCutcheon, Dylan Hawkins...          SET_D_LINE
# 3  [Alex Davis, Elijah Long, Eric Taylor, Henry F...          SET_O_LINE
# 4  [Andrew McKelvey, Charlie McCutcheon, David Ri...  SET_D_LINE_NO_PULL
#
#    is_last_line_b  team_a_score_point_start  team_b_score_point_start  \
# 0            True                         0                         0
# 1            True                         0                         1
# 2            True                         0                         2
# 3           False                         1                         2
# 4            True                         1                         2
#
#   scoring_team score_type  team_a_scored  team_b_scored
# 0        242.0       GOAL          False           True
# 1        242.0       GOAL          False           True
# 2        245.0       GOAL           True          False
# 3        245.0       GOAL           True          False
# 4        245.0       GOAL           True          False
#
# [5 rows x 25 columns]

# %%
# df_output.to_csv("Test_Data_220730_1830.csv", index=False)

# %%
# Making sure there are only 41 times no one scored
df_output.loc[(df_output['team_a_scored'] == False) & (df_output['team_b_scored'] == False)].shape
# Out:
# (41, 25)

# %%
df['event_type'].unique()
# Out:
# array(['START_OF_GAME', 'SET_D_LINE', 'PULL_INBOUNDS', 'BLOCK',
#        'POSSESSION', 'DROP', 'SCORED_ON', 'SET_O_LINE', 'THROWAWAY',
#        'GOAL', 'OUR_MIDPOINT_TIMEOUT', 'SET_O_LINE_NO_PULL',
#        'PULL_OUT_OF_BOUNDS', 'THROWAWAY_CAUSED', 'O_PENALTY_ON_US',
#        'D_PENALTY_ON_US', 'END_OF_Q1', 'D_PENALTY_ON_THEM',
#        'O_PENALTY_ON_THEM', 'INJURY_ON_D', 'SET_D_LINE_NO_PULL', 'STALL',
#        'HALFTIME', 'THEIR_MIDPOINT_TIMEOUT', 'END_OF_Q3', 'GAME_OVER',
#        nan, 'INJURY_ON_O', 'STALL_CAUSED', 'PULL_OUR_OFFSIDES',
#        'REF_TIMEOUT_DISCUSSION???', 'CALLAHAN', 'CALLAHAN_THROWN'],
#       dtype=object)

# %% [raw]
# df['game_point_id'] = df['game_id'].astype(str) + "_" + df['point_id'].astype(str)
# df['home_score']  = np.where((df['home_team'] == df['team_id']) & (df['event_type'].isin(we_score)), 1, 0)
# df['away_score']  = np.where((df['away_team'] == df['team_id']) & (df['event_type'].isin(we_score)), 1, 0)
#
# df['home_score_this_point'] = df.groupby('game_point_id')['home_score'].transform(sum)
# df['away_score_this_point'] = df.groupby('game_point_id')['away_score'].transform(sum)
